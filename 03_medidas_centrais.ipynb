# %% [markdown]
# <a href="https://colab.research.google.com/github/ayportella/statistics_with_python/blob/main/03_medidas_centrais.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## **Medidas de tendência central**

# %%
import numpy as np
import pandas as pd

# %%
enem_sp = pd.read_csv('enem_2019_tratado.csv',
                      sep=',', encoding='iso-8859-1')

# %% [markdown]
# ## Média

# %%
enem_sp['IDADE'].mean()
# Out:
# 20.00796944935984

# %%
enem_sp.IDADE.mean()
# Out:
# 20.00796944935984

# %%
round(enem_sp['IDADE'].mean(),2)
# Out:
# 20.01

# %%
enem_sp.NOTA_REDACAO.mean()
# Out:
# 605.873880203759

# %%
enem_sp['NOTA_MT'].mean()
# Out:
# 492.9669119321324

# %%
enem_sp.NOTA_CN.mean()
# Out:
# 448.20215078946853

# %%
enem_sp.NOTA_CH.mean()
# Out:
# 483.5796221480571

# %%
enem_sp.NOTA_LC.mean()
# Out:
# 493.2945781368933

# %% [markdown]
# ## Mediana

# %%
enem_sp['IDADE'].median()
# Out:
# 18.0

# %%
enem_sp.NOTA_REDACAO.median()
# Out:
# 600.0

# %%
enem_sp.NOTA_MT.median()
# Out:
# 507.7

# %%
enem_sp.NOTA_CN.median()
# Out:
# 476.9

# %%
enem_sp.NOTA_CH.median()
# Out:
# 525.8

# %%
enem_sp['NOTA_LC'].median()
# Out:
# 539.7

# %%
enem_sp.describe()
# Out:
#                IDADE  TP_ESTADO_CIVIL  TP_NACIONALIDADE  TP_ST_CONCLUSAO  \
# count  153712.000000    153712.000000     153712.000000    153712.000000
# mean       20.007969         1.041871          1.027109         1.526498
# std         5.791449         0.351751          0.224340         0.506826
# min        12.000000         0.000000          0.000000         1.000000
# 25%        17.000000         1.000000          1.000000         1.000000
# 50%        18.000000         1.000000          1.000000         2.000000
# 75%        20.000000         1.000000          1.000000         2.000000
# max        91.000000         4.000000          4.000000         4.000000
#
#           CO_ESCOLA  TP_PRESENCA_CN  TP_PRESENCA_CH  TP_PRESENCA_LC  \
# count  6.323500e+04        153711.0        153711.0        153711.0
# mean   3.521220e+07             1.0             1.0             1.0
# std    4.740626e+05             0.0             0.0             0.0
# ...

# %%
round(enem_sp.describe(),1)
# Out:
#           IDADE  TP_ESTADO_CIVIL  TP_NACIONALIDADE  TP_ST_CONCLUSAO  \
# count  153712.0         153712.0          153712.0         153712.0
# mean       20.0              1.0               1.0              1.5
# std         5.8              0.4               0.2              0.5
# min        12.0              0.0               0.0              1.0
# 25%        17.0              1.0               1.0              1.0
# 50%        18.0              1.0               1.0              2.0
# 75%        20.0              1.0               1.0              2.0
# max        91.0              4.0               4.0              4.0
#
#         CO_ESCOLA  TP_PRESENCA_CN  TP_PRESENCA_CH  TP_PRESENCA_LC  \
# count     63235.0        153711.0        153711.0        153711.0
# mean   35212202.1             1.0             1.0             1.0
# std      474062.6             0.0             0.0             0.0
# min        3543.0             1.0             1.0             1.0
# ...

# %% [markdown]
# ## Moda

# %%
enem_sp['IDADE'].mode()
# Out:
# 0    17
# Name: IDADE, dtype: int64

# %%
enem_sp.NOTA_REDACAO.mode()
# Out:
# 0    600.0
# Name: NOTA_REDACAO, dtype: float64

# %%
enem_sp.NOTA_MT.mode()
# Out:
# 0    462.8
# Name: NOTA_MT, dtype: float64

# %%
enem_sp.NOTA_CN.mode()
# Out:
# 0    442.8
# Name: NOTA_CN, dtype: float64

# %%
enem_sp.NOTA_CH.mode()
# Out:
# 0    55.4
# Name: NOTA_CH, dtype: float64

# %%
enem_sp.NOTA_LC.mode()
# Out:
# 0    550.9
# Name: NOTA_LC, dtype: float64

# %% [markdown]
# ## Distribuição

# %%
enem_sp.COMP3.mode()
# Out:
# 0    120.0
# Name: COMP3, dtype: float64

# %%
enem_sp.COMP3.mean()
# Out:
# 120.93838437066964

# %%
enem_sp.COMP3.median()
# Out:
# 120.0

# %%
import plotly.express as px

# %%
grafico =  px.histogram (enem_sp,  x = "COMP3", nbins=15)
grafico.update_layout(width=400,height=400,title_text='Notas do componente 3 da redação - Enem SP 2019')
grafico.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
enem_sp.COMP2.mode()
# Out:
# 0    120.0
# Name: COMP2, dtype: float64

# %%
enem_sp.COMP2.mean()
# Out:
# 129.70626695552042

# %%
enem_sp.COMP2.median()
# Out:
# 120.0

# %%
import plotly.express as px
grafico =  px.histogram (enem_sp,  x = "COMP2", nbins=15)
grafico.update_layout(width=400,height=400,title_text='Notas Componente 2: Redação - Enem SP 2019')
grafico.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...
